# %%
str ="sonukumar"
for i in str:
  print(i)

# %%
N=int(input())
str1=input()
str2='aeiou'
count=0
for i in str1:
    for j in str2:
      
            count=count+1
if count>=1:
    print("true")
elif count==0:
    print("false")
# Out:
#   File "<ipython-input-8-2a4de8d40e03>", line 7
#     if i=j:
#         ^
# SyntaxError: invalid syntax

# %%
print(str)
# Out:
# sonukumar

# %%
for i in str:
  print(i)
# Out:
# s
# o
# n
# u
# k
# u
# m
# a
# r

# %%
x=str.split()
y=x.reverse()
print(x)
print(y)
# Out:
# ['sonukumar']
# None

# %%
str
# Out:
# 'sonukumar'

# %%
l=[1,2,3,4,5]
l.reverse()
l
# Out:
# [5, 4, 3, 2, 1]

# %%
for i in str:
  print(i)

# %%
str[: : -1]
# Out:
# 'ramukunos'

# %%
str1 ="aman"
if str1==str1[: :-1]:
  print("yes")
else:
  print("no")
# Out:
# no

# %%
N=int(input())
A=list(map(int,input().split()))
sum_odd=0
sum_even=0
for i in A:
    if i%2==0:
        sum_even=sum_even + i
    elif i%2!=0:
        sum_odd =sum_odd  + i
if sum_even>sum_odd:
        print("Even")
else:
    print("Odd")
# Out:
# 7
# 1 2 3 4 5 6 7
# Odd

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
s="ankush"
a=s[1: :2]
for i in a:
  print(i)
# Out:
# n
# u
# h
