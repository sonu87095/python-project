# %%
n=int(input())
count=0 
for i in range(n):
  print(i)
# Out:
# 4
# 0
# 1
# 2
# 3

# %%
a=2
b=-4
c=a+b
print(c)
# Out:
# -2

# %%
def name():
  print('my name is sonu')
name()
# Out:
# my name is sonu

# %%
def number(n):
  if n%2==0:
    return "even"
  else:
    return "odd"
x=number(8)
print(x)
# Out:
# even

# %%
def sum(a,b,c):
  add=a+b+c
  return add
print(sum(10,5,5))
# Out:
# 20
