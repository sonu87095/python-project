# %% [markdown]
# Given the list, add a new element 10 at the last index position of the list.

# %%
l = [1,2,3,4]
l.append(10)
l
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# Given the list, add a new element 9 between the elements 2 and 3.

# %%
l = [1,2,3,4]
l.insert(2,9)
l
# Out:
# [1, 2, 9, 3, 4]

# %% [markdown]
# Given the list, reverse the list but with out the last elements using slicing.
#
# - input : l = [3,4,8,9,4,3]
#
# - output: [4,9,8,4,3]

# %%
l = [3,4,8,9,4,3]
l[-2::-1]
# Out:
# [4, 9, 8, 4, 3]

# %% [markdown]
# Using slicing, achieve the following output as mentioned below.
#
# - input: l = ['Pushap', 'Anna', 7, 8, 9, [0,1]]
#
# - output: 'annA'

# %%
l=['Pushap', 'Anna', 7, 8, 9, [0,1]]
l[1:2][::-1]
# Out:
# ['Anna']

# %% [markdown]
# Given the list, achieve the following output
#
# - input: l = ['Pushap', 'Anna', 7, 8, 9, [0,1]]
# - output: ['Pushap', 'Anna', 7, 8, 9, [0]]

# %%
l = ['Pushap', 'Anna', 7, 8, 9, [0,1]]
l[-1].remove(1)
l
# Out:
# ['Pushap', 'Anna', 7, 8, 9, [0]]

# %%
#### string 3. Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. 
#If the string length is less than 2, return instead of the empty string. Go to the editor
# Sample String : 'w3resource'
# Expected Result : 'w3ce'
# Sample String : 'w3'
# Expected Result : 'w3w3'
# Sample String : ' w'
# Expected Result : Empty String
def string_both_ends(str):
  if len(str) < 2:
    return ''

  return str[0:2] + str[-2:]

print(string_both_ends('w3resource'))
print(string_both_ends('w3'))
print(string_both_ends('w'))
# Out:
# w3ce
# w3w3

# %%
b = "w3resource"
b[0:2]
# Out:
# 'w3'

# %%
def first3_last2(str):
  if len(str)<2:
    return " "
  return str[0:3] +str[-2::]
print(first3_last2("sonukumar"))
print(first3_last2("so"))
print(first3_last2("s"))
# Out:
# sonar
# soso

# %%
# 4. Write a Python program to get a string from a given string 
#where all occurrences of its first char have been changed to '$', except the first char itself. Go to the editor
# Sample String : 'restart'
# Expected Result : 'resta$t'

# %%
a = 'restart'
b = a[0]
c=a.replace(b,"$")
d = b + c[1:]
print(d)
# Out:
# resta$t

# %%
# 5. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string. Go to the editor
# Sample String : 'abc', 'xyz'
# Expected Result : 'xyc abz'
#a ,  b = 'abc', 'xyz'

# %%
a = "sonu"
a.split(" ")
print(a)
# Out:
# sonu
