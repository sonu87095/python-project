# %% [markdown]
# pandas = panel data system ,

# %%
import pandas as pd

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford","audi", "merc"],
  'passings': [3, 7, 2,4,5]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
# 3   audi         4
# 4   merc         5

# %%
myfamily = {
    'engineers':["sonu","ranjit", "guddu"],
    "salary": [60000,40000,30000]
     }
myfam = pd.DataFrame(myfamily)
print(myfam)
# Out:
#   engineers  salary
# 0      sonu   60000
# 1    ranjit   40000
# 2     guddu   30000

# %% [markdown]
#                     pandas series

# %%
a = [1,2,3,4,5]
b = pd.Series(a)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(b[0])
# Out:
# 1

# %%
print(b[2])
# Out:
# 3

# %%
#######                              Create Labels

# %%
a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
p = [6,7,8]
myarr = pd.Series(p,index = ["x","y","z"])
print(myarr)
# Out:
# x    6
# y    7
# z    8
# dtype: int64

# %%
print(myarr['x'])
# Out:
# 6

# %%
##Key/Value Objects as Series

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day2", "day3"])

print(myvar)
# Out:
# day2    380
# day3    390
# dtype: int64

# %%
exercise = {"monday": "ihr","tue": "2hr","thu":"3hr","fri":"4hr","sat":"3omin","sun":"nowork"}
myex= pd.Series(exercise)
print(myex)
# Out:
# monday       ihr
# tue          2hr
# thu          3hr
# fri          4hr
# sat        3omin
# sun       nowork
# dtype: object

# %%
myex = pd.Series(exercise,index = ["monday","tue"])
print(myex)
# Out:
# monday    ihr
# tue       2hr
# dtype: object

# %%
import pandas as pd

# %%
import numpy as np

# %%
obj1 = pd.Series(np.tile([1,2],2))

# %%
obj1                    # np.tile function print the list as many times as u want
# Out:
# 0    1
# 1    2
# 2    1
# 3    2
# dtype: int64

# %%
# index is not necessary to be in sequence 
obj2 = pd.Series(12,index = range(1,6,2))
obj2
# Out:
# 1    12
# 3    12
# 5    12
# dtype: int64

# %%
obj3= pd.Series(200,index = range(2022,2029,2))
obj3
# Out:
# 2022    200
# 2024    200
# 2026    200
# 2028    200
# dtype: int64

# %%
import pandas as pd 
ind = ['jan',"feb","march"]
values = [31,28,31]
obj1 = pd.Series(index =ind,data = values )
obj1
# Out:
# jan      31
# feb      28
# march    31
# dtype: int64

# %%
obj1.index            #it gives the index
# Out:
# Index(['jan', 'feb', 'march'], dtype='object')

# %%
obj1.values           # it provides the values of the object
# Out:
# array([31, 28, 31])

# %%
obj1.dtype
# Out:
# dtype('int64')

# %%
obj1.size
# Out:
# 3

# %%
obj1.size
# Out:
# 3

# %%
type(obj1)
# Out:
# pandas.core.series.Series

# %%
obj1.shape
# Out:
# (3,)

# %%
print(obj1.nbytes)
# Out:
# 24

# %%
obj2 = pd.Series()
print(obj2.empty)
# Out:
# True
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
#######           modifying series object values 
a = [1,2,3,4,5]
b = pd.Series(a)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
b[0]
# Out:
# 1

# %%
b[0]=8
b[2]=9
b
# Out:
# 0    8
# 1    2
# 2    9
# 3    4
# 4    5
# dtype: int64

# %%
###### renaming indexes 
b.index = ['a','b','c','d','e']
b
# Out:
# a    8
# b    2
# c    9
# d    4
# e    5
# dtype: int64

# %%
#### head(5), tail(5 ) gives the top 5 and bottom rows of any object
b.head(2)
# Out:
# a    8
# b    2
# dtype: int64

# %%
b
# Out:
# a    8
# b    2
# c    9
# d    4
# e    5
# dtype: int64

# %%
b+2
#### every elements of object will be increase by 2
# Out:
# a    10
# b     4
# c    11
# d     6
# e     7
# dtype: int64

# %%
#### arithmetic on series object

# %%
import pandas as pd
obj1 = pd.Series([1,2,3,4])
obj2 = pd.Series([4,5,6,7])
obj3 = pd.Series([3,2,1,2])
print(obj1+obj2+obj3)
# Out:
# 0     8
# 1     9
# 2    10
# 3    13
# dtype: int64

# %%
print(obj1>2)             # filtering
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
print(obj1[obj1>2])      # filtering
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
###### sorting series values 
obj3.sort_values()
# Out:
# 2    1
# 1    2
# 3    2
# 0    3
# dtype: int64

# %%
obj1 = pd.Series([11,3,28,4])        
obj1.sort_values()
# Out:
# 1     3
# 3     4
# 0    11
# 2    28
# dtype: int64

# %%
obj1.sort_values(ascending=False)        # it will arrange the data in descending order
# Out:
# 2    28
# 0    11
# 3     4
# 1     3
# dtype: int64

# %%
obj1.sort_index(ascending=False)
# Out:
# 3     4
# 2    28
# 1     3
# 0    11
# dtype: int64

# %%
#### creating DataFrame object by dict 
import pandas as pd
dict1 = { "students": ["sonu","neha","arti"],
         "marks": [60,70,80],
         "sports": ["cricket","luddo","badminton"]}
df = pd.DataFrame(dict1,index =["p","q","r"])
print(df)
# Out:
#   students  marks     sports
# p     sonu     60    cricket
# q     neha     70      luddo
# r     arti     80  badminton

# %%
dict1 = { "sales":{ "name":"sonu","age":25,"sex": "male"},
         "marketing":{'name': 'neha',"age":24,'sex': "female"}}
df = pd.DataFrame(dict1)
print(df)
# Out:
#      sales marketing
# name  sonu      neha
# age     25        24
# sex   male    female

# %%
dict1 = { "sales":{ "name":"sonu","age":25,"sex": "male"},
         "marketing":{'name': 'neha',"age":24}}
df = pd.DataFrame(dict1)
print(df)
# Out:
#      sales marketing
# name  sonu      neha
# age     25        24
# sex   male       NaN

# %%
dict1 = { "sales":{ "name":"sonu","age":25,"sex": "male"},
         "marketing":{'name': 'neha',"age":24,'salary': 100000}}
df = pd.DataFrame(dict1)
print(df)
# Out:
#        sales marketing
# name    sonu      neha
# age       25        24
# sex     male       NaN
# salary   NaN    100000

# %%
import pandas as pd 
dict1 = { "roll":12, "name": "sonu","marks":100}
dict2 =  { "roll":11, "name": "monu","marks":10}
dict3 = { "roll":2, "name": "tonu","marks":150}
list1 = [dict1,dict2,dict3]
df = pd.DataFrame(list1)
print(df)
# Out:
#    roll  name  marks
# 0    12  sonu    100
# 1    11  monu     10
# 2     2  tonu    150

# %%
import pandas as pd 
dict1 = { "roll":12, "name": "sonu","marks":100}
dict2 =  { "roll":11, "name": "monu","marks":10}
dict3 = { "roll":2, "name": "tonu","marks":150}
list1 = [dict1,dict2,dict3]
df = pd.DataFrame(list1,index = ["secA","secB",'secC'])
print(df)
# Out:
#       roll  name  marks
# secA    12  sonu    100
# secB    11  monu     10
# secC     2  tonu    150

# %%
list2 = [[1,2,3],[4,5,6],[7,8,9]]
df = pd.DataFrame(list2,columns =["col1","col2","col3"])
print(df)
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
import pandas as pd 
import numpy as np 
arr1 = np.array([[1,2,3],[4,5,6]])
df = pd.DataFrame(arr1, columns = ["a",'b',"c"])
print(df)
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
import pandas as pd 
staff = pd.Series([20,40,44])
salary = pd.Series([1000,15000,25000])
school = {'people':staff,'amount':salary}
df = pd.DataFrame(school)
print(df)
# Out:
#    people  amount
# 0      20    1000
# 1      40   15000
# 2      44   25000

# %%
import pandas as pd           # creating dataframe object by series 
staff = pd.Series([20,40,44])
salary = pd.Series([1000,15000,25000])
school = {'people':staff,'amount':salary}
df = pd.DataFrame(school)
print(df["people"])
# Out:
# 0    20
# 1    40
# 2    44
# Name: people, dtype: int64

# %%
# creating a dataframe by using data frame 
import pandas as pd 
obj1 = pd.DataFrame([[1,2,3],[4,5,6]])
obj2 = pd.DataFrame(obj1)
print(obj2)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
obj1.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
obj2.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
obj2.axes
# Out:
# [RangeIndex(start=0, stop=2, step=1), RangeIndex(start=0, stop=3, step=1)]

# %%
len(obj2)     # count the number of rows
# Out:
# 2

# %%
obj1.count()
obj1.count(0)
obj1.count(axis='index')
# Out:
# 0    2
# 1    2
# 2    2
# dtype: int64

# %%
obj1.count()
obj1.count(0)
# Out:
# 0    2
# 1    2
# 2    2
# dtype: int64

# %%
df.count()
# Out:
# people    3
# amount    3
# dtype: int64

# %%
df.count(axis = 'columns')
# Out:
# 0    2
# 1    2
# 2    2
# dtype: int64

# %%
dict1 = { "sales":{ "name":"sonu","age":25,"sex": "male"},
         "marketing":{'name': 'neha',"age":24,'salary': 100000}}
df = pd.DataFrame(dict1)
print(df)
# Out:
#        sales marketing
# name    sonu      neha
# age       25        24
# sex     male       NaN
# salary   NaN    100000

# %%
df.count(axis= 'columns')
# Out:
# name      2
# age       2
# sex       1
# salary    1
# dtype: int64

# %%
#### transposing a dataframe; its converted rows int0 columns 
df.T
# Out:
#            name age   sex  salary
# sales      sonu  25  male     NaN
# marketing  neha  24   NaN  100000

# %%
#### selecting accesing dataframe columns 
df['sales']
# Out:
# name      sonu
# age         25
# sex       male
# salary     NaN
# Name: sales, dtype: object

# %%
############# loc and iloc function 
#   dataframeobject.loc[start_row:end_row , start_column:end_column] when then name of rows and column are known 
# dfo.iloc[start_row_index:end_row_index , start_column_index:end_column_index]                          its used when rows and column name are not given

# %%
## obj.column_name["rows_name"]  gives the intersection values # obj.at["column_name", "rows_name"] it returns the intersected values 
# obj.iat[3,2]  its take index rows and column as input

# %%
### we can use extra column in obj by obj["col_name"] = [values]
# to delete any rows , del obj["column"]   it will delete the column 
# we can also use drop function obj.drop["col1","col2",axis=1 ]

# %%
# renaming rows and column 
# to change rows obj.rename({"old_name":"new_name",...}) it change temporarily 
#obj.rename({"old_name":"new_name",...},inplace='True') its completely change the data base value

# %%
sales = { 'year1':{"qtr1":1200,"qtr2":1900,"qtr3":1540,"qtr4":2000},
         "year2":{"qtr1":1900,"qtr2":1500,"qtr3":1505,"qtr4":3000},
         "year3":{"qtr1":1600,"qtr2":1800,"qtr3":1540,"qtr4":2000},
         "year4":{"qtr1":1200,"qtr2":1900,"qtr3":1540,"qtr4":2000}}
print(sales)
# Out:
# {'year1': {'qtr1': 1200, 'qtr2': 1900, 'qtr3': 1540, 'qtr4': 2000}, 'year2': {'qtr1': 1900, 'qtr2': 1500, 'qtr3': 1505, 'qtr4': 3000}, 'year3': {'qtr1': 1600, 'qtr2': 1800, 'qtr3': 1540, 'qtr4': 2000}, 'year4': {'qtr1': 1200, 'qtr2': 1900, 'qtr3': 1540, 'qtr4': 2000}}

# %%
import pandas as pd

# %%
obj1 = pd.DataFrame(sales)
print(obj1)
# Out:
#      year1 year2 year3 year4
# qtr1  1200  1900  1600  1200
# qtr2  1900  1500  1800  1900
# qtr3  1540  1505  1540  1540
# qtr4  2000  3000  2000  2000

# %%
# itterrows(),itteritems()
for (a,b ) in obj1.iterrows():
  #print(a,b)
  print("rowindex",a,'\n.value=\n',b)
# Out:
# rowindex qtr1
# .value=
#  year1    1200
# year2    1900
# year3    1600
# year4    1200
# Name: qtr1, dtype: object
# rowindex qtr2
# .value=
#  year1    1900
# year2    1500
# year3    1800
# year4    1900
# Name: qtr2, dtype: object
# rowindex qtr3
# .value=
#  year1    1540
# year2    1505
# year3    1540
# year4    1540
# Name: qtr3, dtype: object
# rowindex qtr4
# .value=
#  year1    2000
# year2    3000
# year3    2000
# year4    2000
# Name: qtr4, dtype: object

# %%
for (a,b ) in obj1.iteritems():
  #print(a,b)
  print("rowindex",a,'\n.value=\n',b)
# Out:
# rowindex year1
# .value=
#  qtr1       1200
# quater2    1900
# qtr3       1540
# qtr4       2000
# quater5    1000
# Name: year1, dtype: object
# rowindex year2
# .value=
#  qtr1       1900
# quater2    1500
# qtr3       1505
# qtr4       3000
# quater5     333
# Name: year2, dtype: object
# rowindex year3
# .value=
#  qtr1       1600
# quater2    1800
# qtr3       1540
# qtr4       2000
# quater5     666
# Name: year3, dtype: object
# rowindex year4
# .value=
#  qtr1       1000.0
# quater2    2000.0
# qtr3       3000.0
# qtr4       4000.0
# quater5    2000.0
# Name: year4, dtype: float64

# %%
obj1
# Out:
#      year1 year2 year3 year4
# qtr1  1200  1900  1600  1200
# qtr2  1900  1500  1800  1900
# qtr3  1540  1505  1540  1540
# qtr4  2000  3000  2000  2000

# %%
print("sonu")
# Out:
# sonu	kumar

# %%
obj1.year1                  # to access single column
# Out:
# qtr1    1200
# qtr2    1900
# qtr3    1540
# qtr4    2000
# Name: year1, dtype: object

# %%
obj1.year1['qtr4']             # to access particular values
# Out:
# '2000'

# %%
obj1.at['qtr2','year4']     # another method to find individual values by at
# Out:
# 1900

# %%
obj1.iat[2,1]         # it for index
# Out:
# 1505

# %%
########## adding and modifying column 
obj1["year5"]=[1000,2000,3000,4000]       # its add column 
obj1
# Out:
#      year1 year2 year3  year4  year5
# qtr1  1200  1900  1600   1000   1000
# qtr2  1900  1500  1800   2000   2000
# qtr3  1540  1505  1540   3000   3000
# qtr4  2000  3000  2000   4000   4000

# %%
# for adding rows 
obj1.at["qtr5",:] =[1000,333,666,2000,3000]
obj1
# Out:
#      year1 year2 year3   year4   year5
# qtr1  1200  1900  1600  1000.0  1000.0
# qtr2  1900  1500  1800  2000.0  2000.0
# qtr3  1540  1505  1540  3000.0  3000.0
# qtr4  2000  3000  2000  4000.0  4000.0
# qtr5  1000   333   666  2000.0  3000.0

# %%
del obj1['year5']

# %%
# renaming rows and column # its rename the temporarily 
obj1.rename(index ={"qtr5":"quater5","qtr2":"quater2" })
# Out:
#         year1 year2 year3   year4
# qtr1     1200  1900  1600  1000.0
# quater2  1900  1500  1800  2000.0
# qtr3     1540  1505  1540  3000.0
# qtr4     2000  3000  2000  4000.0
# quater5  1000   333   666  2000.0

# %%
# if you want to change permananetly 
obj1.rename(index ={"qtr5":"quater5","qtr2":"quater2" },inplace = True)
obj1
# Out:
#         year1 year2 year3   year4
# qtr1     1200  1900  1600  1000.0
# quater2  1900  1500  1800  2000.0
# qtr3     1540  1505  1540  3000.0
# qtr4     2000  3000  2000  4000.0
# quater5  1000   333   666  2000.0

# %%
############ for renaming the column 
obj1.rename(columns  ={"year1":"yrs1","year2":"yrs2" })
# Out:
#          yrs1  yrs2 year3   year4
# qtr1     1200  1900  1600  1000.0
# quater2  1900  1500  1800  2000.0
# qtr3     1540  1505  1540  3000.0
# qtr4     2000  3000  2000  4000.0
# quater5  1000   333   666  2000.0

# %%
# binary operation on pandas 
data1 = { "A":[1,2,3],"B":
        [4,5,6],"C":[7,8,9]}
df1 = pd.DataFrame(data1)
df1
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
data2 = { "A":[10,20,30],"B":
        [40,50,60],"C":[70,80,90]}
df2 = pd.DataFrame(data2)
df2
# Out:
#     A   B   C
# 0  10  40  70
# 1  20  50  80
# 2  30  60  90

# %%
df1+df2
# Out:
#     A   B   C
# 0  11  44  77
# 1  22  55  88
# 2  33  66  99

# %%
df1.add(df2)
# Out:
#     A   B   C
# 0  11  44  77
# 1  22  55  88
# 2  33  66  99

# %%
obj1
# Out:
#         year1 year2 year3   year4
# qtr1     1200  1900  1600  1000.0
# quater2  1900  1500  1800  2000.0
# qtr3     1540  1505  1540  3000.0
# qtr4     2000  3000  2000  4000.0
# quater5  1000   333   666  2000.0

# %%
obj1['year1']
# Out:
# qtr1       1200
# quater2    1900
# qtr3       1540
# qtr4       2000
# quater5    1000
# Name: year1, dtype: object

# %%
sum1 = 0 
for i in obj1['year1']:
  print(i)
# Out:
# 1200
# 1900
# 1540
# 2000
# 1000

# %%
df1-df2
# Out:
#     A   B   C
# 0  -9 -36 -63
# 1 -18 -45 -72
# 2 -27 -54 -81

# %%
df1.sub(df2)
# Out:
#     A   B   C
# 0  -9 -36 -63
# 1 -18 -45 -72
# 2 -27 -54 -81

# %%
df1.rsub(df2)
# Out:
#     A   B   C
# 0   9  36  63
# 1  18  45  72
# 2  27  54  81

# %%
df1*df2
# Out:
#     A    B    C
# 0  10  160  490
# 1  40  250  640
# 2  90  360  810

# %%
obj1
# Out:
#         year1 year2 year3   year4
# qtr1     1200  1900  1600  1000.0
# quater2  1900  1500  1800  2000.0
# qtr3     1540  1505  1540  3000.0
# qtr4     2000  3000  2000  4000.0
# quater5  1000   333   666  2000.0

# %%
obj1["year1"]+obj1["year2"]
# Out:
# qtr1           3100
# quater2        3400
# qtr3           3045
# qtr4       20003000
# quater5        1333
# dtype: object

# %%
########### data visualisation

# %%
import matplotlib as mt

# %%
import matplotlib.pyplot as plt

# %%
####read csv

# %%
# df = pd.read_csv('data.csv')
# print(df)    , t print wholse csv use print(df.to_string())

# %% [markdown]
# You can check your system's maximum rows with the (pd.options.display.max_rows) )statement.

# %%
### df.head() it is used to print the top 5 rows of the data , df.tail() use for bottom , df.info() for more information

# %% [markdown]
# **Pandas - Cleaning Empty Cells** ,new_df = df.dropna() dropna() is used to remove the empty cell
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.
#
# If you want to change the original DataFrame, use the inplace = True argument:

# %% [markdown]
# Replace Empty Values
# The fillna() method allows us to replace empty cells with a value:
# df.fillna(130, inplace = True)
# **Replace Only For Specified Columns**
# df = pd.read_csv('data.csv')
#
# df["Calumn_name"].fillna(130, inplace = True)

# %% [markdown]
# **Replace Using Mean, Median, or Mode**
# import pandas as pd
#
# df = pd.read_csv('data.csv')
#
# x = df["Calories"].mean()
#
# df["Calories"].fillna(x, inplace = True)

# %% [markdown]
# **Pandas - Cleaning Data of Wrong Format**
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

# %% [markdown]
# **Convert Into a Correct Format**
# Pandas has a to_datetime() method for this: used to convert into date
# eg
# import pandas as pd
#
# df = pd.read_csv('data.csv')
#
# df['Date'] = pd.to_datetime(df['Date'])
#
# print(df.to_string())
# Remove rows with a NULL value in the "Date" column:
# df.dropna(subset=['Date'], inplace = True)
