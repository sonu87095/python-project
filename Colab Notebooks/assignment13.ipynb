# %%
#- Create a class, Rectangle. Its __init__() method should take self, angle1, angle2,
#angle3, angle4 as arguments
class Rectangle:
  number_of_sides=4
  def __init__(self,angle1,angle2,angle3,angle4):
    self.angle1=angle1
    self.angle2=angle2
    self.angle3=angle3
    self.angle4=angle4
    def check_angles(self,angle1,angle2,angle3,angle4):
      if (angle1+angle2+angle3+angle4)==360:
        print(True)
      else:
        print(False)
my_rectangle = Rectangle(90,90,100,80)
my_rectangle.check_angles()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-e9ef52ee60dc> in <module>()
#      14         print(False)
#      15 my_rectangle = Rectangle(90,90,100,80)
# ---> 16 my_rectangle.check_angles()
#      17
#      18
#
# AttributeError: 'Rectangle' object has no attribute 'check_angles'
