# %%
#Create a set 
num_set = set([0, 1, 2, 3, 4, 5])
for n in num_set:
  print(n,end=" ")
print("\n\nCreating a set using string:")
char_set = set("w3resource")  
# Iterating using for loop
for val in char_set:
    print(val, end=' ')
# Out:
# 0 1 2 3 4 5
#
# Creating a set using string:
# c s r 3 e u o w

# %%
#Create a new set
num_set = set([0, 1, 2, 3, 4, 5])
print("Original set elements:")
print(num_set)
print("\nRemove 0 from the said set:")
num_set.discard(0)
print(num_set)
print("\nRemove 5 from the said set:")
num_set.discard(5)
print(num_set)
print("\nRemove 2 from the said set:")
num_set.discard(5)
print(num_set)
print("\nRemove 7 from the said set:")
num_set.discard(15)
# Out:
# Original set elements:
# {0, 1, 2, 3, 4, 5}
#
# Remove 0 from the said set:
# {1, 2, 3, 4, 5}
#
# Remove 5 from the said set:
# {1, 2, 3, 4}
#
# Remove 2 from the said set:
# {1, 2, 3, 4}
#
# Remove 7 from the said set:

# %%
#Write a Python program to check if two given sets have no elements in common.

# %%
x = {1,2,3,4}
y = {4,5,6,7}
print(x.isdisjoint(y))
# Out:
# False

# %%
a = ["sonu","gudddu","arti","anjali"]
b = ["neha","ashu","priyanka","pc"]
for i,j in zip(a,b):
  print(i,j)
# Out:
# sonu neha
# gudddu ashu
# arti priyanka
# anjali pc

# %%
a = [13,14,15,16]
b = [7,8,16,10]
for i , j in zip(a,b):
    if i<=15 and j <=7:
        print("Boarding")
    else:
        print("Stop")
# Out:
# Boarding
# Stop
# Stop
# Stop

# %%
num=int(input())
amt=num-80
u=0
if amt<=150:
    u=int(amt/3)
else:
    amt=amt-150
    u+=50
    if amt<=500:
        b=int(amt/5)
        u+=b
    else:
        amt=amt-500
        u+=100
        c=int(amt/10)
        u+=c
print(u)
# Out:
# 500
# 104

# %%
n = int(input())
students_marks = {}
for i in range(n):
  x = name,*score= input().split()
  scores = list(map(float,score))
  students_marks[name]=scores
z = input()
y = students_marks [z]
sum1 = 0 
for j in y :
  sum1 = sum1+j
print("{0:.2f}".format(sum1/3))
# Out:
# 3
# sonu 10 20 30
# neha 10 30 40
# kiran 20 40 60
# kiran
# 40.00

# %%
x = name,*score= input().split()
print(x)
# Out:
# sonu 1 2 3 4
# ['sonu', '1', '2', '3', '4']

# %%
 n = int(input())	
students_marks = {}
for i in range(n):	  
  x = name,*score= input().split()
  scores = list(map(float,score))	  
  students_marks[name]=scores
z = input()
y = students_marks[z]
sum1 = 0 
for j in y :
  sum1 = sum1+j
print("{0:.2f}".format(sum1/3))
# Out:
# 3
# neha 20 30 40
# sonu 20 40 60
# guddu 20 70 30
# sonu
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-9978585279b5> in <module>()
#       6   students_marks[name]=scores
#       7 z = input()
# ----> 8 y = students_marks [z]
#       9 sum1 = 0
#      10 for j in y :
#
# KeyError: 'sonu '

# %%
a = "sonu kumar"
print(type(a))
a = a.split(" ")
print(a)
print(type(a))
a="-".join(a)
print(a)
# Out:
# <class 'str'>
# ['sonu', 'kumar']
# <class 'list'>
# sonu-kumar
