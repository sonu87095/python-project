# %%
string = "abracadabra"
l = list(string)
l[5] = 'k'
string = ''.join(l)
print(string)
# Out:
# abrackdabra

# %%
string= "sonukumar"
l = list(string)
l[0]='m'
string= ''.join(l)
print(string)
# Out:
# monukumar

# %%
string = "abracadabra"

# %%
string = string[:5] + "k" + string[6:]
print (string)
# Out:
# abrackdabra

# %%
string = string[:5]

# %%
def count_substring(string, sub_string):
    count = 0
    for i in range(len(string)):
        if string[i:].startswith(sub_string):
            count += 1
    return count
count_substring('ABCDCDC','CDC')
# Out:
# 2

# %%
def count_substring(string,sub_string):
  count = 0 
  for i in range(len(string)):
    if string[i:].startswith(sub_string):
      count=count+1
  return count
count_substring('abcdcd','cd')
# Out:
# 2

# %%
width = 20 
print ('HackerRank'.ljust(width,'-'))
# Out:
# HackerRank----------

# %%
s = input()
for x in s[:].split():
    s = s.replace(x, x.capitalize())
print(s)
# Out:
# sonu kumar
# Sonu Kumar

# %%
s = "sonu kumar"
for i in s.split():
  s= s.replace(i ,i.capitalize())
print(s)
# Out:
# Sonu Kumar

# %%
d = {}
a = ['sonu','guddu','arti']
b =[100,200,300]
d.items()
d
# Out:
# {}

# %%
# Out:
# {'arti': [100, 200, 300], 'guddu': [100, 200, 300], 'sonu': [100, 200, 300]}

# %%
d.keys()
# Out:
# dict_keys(['sonu', 'guddu', 'arti'])

# %%
d.values()
# Out:
# dict_values([[100, 200, 300], [100, 200, 300], [100, 200, 300]])

# %%
d.items()
# Out:
# dict_items([('sonu', [100, 200, 300]), ('guddu', [100, 200, 300]), ('arti', [100, 200, 300])])

# %%
for i in a:
  for j in b:
    d[i] =j
  break
    
d
# Out:
# {'arti': 100, 'guddu': 100, 'sonu': 300}
