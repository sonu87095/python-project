# %%
import csv

# %%
#ques1
path='/content/drive/MyDrive/CSV Assignment/births_usa.csv'
with open(path,'r') as f:
  reader=csv.reader(f)
  birts_data=[]
  for j,i in enumerate(reader):

    birts_data.append(i)

# %%
birts_data[:20]
# Out:
# [['year', 'month', 'date_of_month', 'day_of_week', 'births'],
#  ['2000', '1', '1', '6', '9083'],
#  ['2000', '1', '2', '7', '8006'],
#  ['2000', '1', '3', '1', '11363'],
#  ['2000', '1', '4', '2', '13032'],
#  ['2000', '1', '5', '3', '12558'],
#  ['2000', '1', '6', '4', '12466'],
#  ['2000', '1', '7', '5', '12516'],
#  ['2000', '1', '8', '6', '8934'],
#  ['2000', '1', '9', '7', '7949'],
#  ['2000', '1', '10', '1', '11668'],
#  ['2000', '1', '11', '2', '12611'],
#  ['2000', '1', '12', '3', '12398'],
#  ['2000', '1', '13', '4', '11815'],
#  ['2000', '1', '14', '5', '12180'],
#  ['2000', '1', '15', '6', '8525'],
#  ['2000', '1', '16', '7', '7657'],
#  ['2000', '1', '17', '1', '10824'],
#  ['2000', '1', '18', '2', '12350'],
#  ['2000', '1', '19', '3', '12405']]

# %%
rows=birts_data[1:]

# %%
d={}
for i in l[1:]:
  if i[1] in d.keys():
    d[i[1]]=d[i[1]]+int(i[4])
  else:
    d[i[1]]=int(i[4])
print(d)

# %%
d
# Out:
# {'1': 5072588,
#  '10': 5302865,
#  '11': 5008750,
#  '12': 5194432,
#  '2': 4725693,
#  '3': 5172961,
#  '4': 4960750,
#  '5': 5195445,
#  '6': 5163360,
#  '7': 5450418,
#  '8': 5540170,
#  '9': 5399592}

# %%
month_d={'1':'January','2':'Feb','3':'march','4':'april','5':'may','6':'june','7':'july','8':'augest','9':'sep','10':'oct','11':'nov','12':'dec'}
month_l=['January','Feb','march','april','may','june','july','augest','sep','oct','nov','dec']
for i,j in enumerate(month_l):
  #print(i,j)

  print(j,d[str(i+1)],sep='-')
# Out:
# January-5072588
# Feb-4725693
# march-5172961
# april-4960750
# may-5195445
# june-5163360
# july-5450418
# augest-5540170
# sep-5399592
# oct-5302865
# nov-5008750
# dec-5194432

# %%
#ques2
d_birth={}
for i in rows:
  if i[3] in d_birth.keys():
    d_birth[i[3]]=d_birth[i[3]]+int(i[4])
  else:
    d_birth[i[3]]=int(i[4])

# %%
d_birth
# Out:
# {'1': 9316001,
#  '2': 10274874,
#  '3': 10109130,
#  '4': 10045436,
#  '5': 9850199,
#  '6': 6704495,
#  '7': 5886889}

# %%
#ques 3
path='/content/drive/MyDrive/CSV Assignment/temperatures.csv'
with open(path,'r') as f:
  reader=csv.reader(f)
  data_temp=[]
  for i in reader:
    data_temp.append(i)

# %%
for i in data_temp[:50]:
  print(i)
# Out:
# ['date', 'actual_mean_temp', 'actual_min_temp', 'actual_max_temp', 'average_min_temp', 'average_max_temp', 'record_min_temp', 'record_max_temp', 'record_min_temp_year', 'record_max_temp_year', 'actual_precipitation', 'average_precipitation', 'record_precipitation']
# ['2014-7-1', '70', '63', '77', '63', '82', '52', '107', '1886', '1985', '0', '0', '0.09']
# ['2014-7-2', '70', '62', '77', '63', '82', '51', '102', '1887', '1985', '0', '0', '0']
# ['2014-7-3', '72', '63', '81', '63', '82', '52', '100', '1902', '1985', '0', '0', '0']
# ['2014-7-4', '72', '62', '82', '63', '82', '53', '103', '1900', '1907', '0', '0', '0.07']
# ['2014-7-5', '75', '64', '86', '63', '82', '50', '100', '1886', '1907', '0', '0', '0.02']
# ['2014-7-6', '73', '64', '81', '63', '82', '51', '94', '1894', '1992', '0', '0', '0.03']
# ['2014-7-7', '77', '64', '89', '63', '83', '51', '96', '1894', '1954', '0', '0', '0.02']
# ['2014-7-8', '77', '68', '86', '63', '83', '51', '95', '1894', '1886', '0', '0', '0.13']
# ...

# %%
rows=data_temp[1:]

# %%
d_max={}
for i in rows:
  x='-'.join(i[0].split('-')[:-1])
  if x in d_max.keys():
    if d_max[x]<int(i[3]):
      d_max[x]=int(i[3])

  else:
    d_max[x]=int(i[3])

# %%
d_max
# Out:
# {'2014-10': 98,
#  '2014-11': 90,
#  '2014-12': 83,
#  '2014-7': 92,
#  '2014-8': 91,
#  '2014-9': 103,
#  '2015-1': 85,
#  '2015-2': 88,
#  '2015-3': 93,
#  '2015-4': 92,
#  '2015-5': 84,
#  '2015-6': 91}

# %%
d_min={}
for i in rows:
  x='-'.join(i[0].split('-')[:-1])
  if x in d_min.keys():
    if d_min[x]>int(i[2]):
      d_min[x]=int(i[2])

  else:
    d_min[x]=int(i[2])

# %%
d_max
# Out:
# {'2014-10': 98,
#  '2014-11': 90,
#  '2014-12': 83,
#  '2014-7': 92,
#  '2014-8': 91,
#  '2014-9': 103,
#  '2015-1': 85,
#  '2015-2': 88,
#  '2015-3': 93,
#  '2015-4': 92,
#  '2015-5': 84,
#  '2015-6': 91}

# %%
print(d_max)
# Out:
# {'2014-7': 92, '2014-8': 91, '2014-9': 103, '2014-10': 98, '2014-11': 90, '2014-12': 83, '2015-1': 85, '2015-2': 88, '2015-3': 93, '2015-4': 92, '2015-5': 84, '2015-6': 91}

# %%
for i in d_min.items():
  print(i)
# Out:
# ('2014-7', 62)
# ('2014-8', 63)
# ('2014-9', 61)
# ('2014-10', 59)
# ('2014-11', 51)
# ('2014-12', 39)
# ('2015-1', 37)
# ('2015-2', 46)
# ('2015-3', 48)
# ('2015-4', 49)
# ('2015-5', 50)
# ('2015-6', 58)

# %%
#que1
path='/content/drive/MyDrive/CSV Assignment/covid.csv'
with open(path,'r') as f:
  reader=csv.reader(f)
  data_covid=[]
  for i in reader:
    data_covid.append(i)

# %%
for i in data_covid[:50]:
  print(i)
# Out:
# ['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths', 'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population']
# ['Andaman and Nicobar', '10039', '0', '9910', '129', '0.0', '98.72', '1.28', '100896618']
# ['Andhra Pradesh', '2319869', '62', '2305076', '14731', '0.0', '99.36', '0.63', '128500364']
# ['Arunachal Pradesh', '64504', '1', '64207', '296', '0.0', '99.54', '0.46', '658019']
# ['Assam', '724225', '4', '716235', '7986', '0.0', '98.9', '1.1', '290492']
# ['Bihar', '830702', '43', '818403', '12256', '0.01', '98.52', '1.48', '40100376']
# ['Chandigarh', '92293', '67', '91061', '1165', '0.07', '98.67', '1.26', '79502477']
# ['Chhattisgarh', '1152370', '36', '1138300', '14034', '0.0', '98.78', '1.22', '28900667']
# ['Dadra and Nagar Haveli and Daman and Diu', '11441', '0', '11437', '4', '0.0', '99.97', '0.03', '231502578']
# ['Delhi', '1903189', '2138', '1874851', '26200', '0.11', '98.51', '1.38', '773997']
# ...

# %%
rows=data_covid[1:]
cols=data_covid[0]

# %%
d={'State':[], 'Total Deaths':[], 'Total Discharged':[]}

# %%
d['State'].append(1)

# %%
d
# Out:
# {'State': [1], 'Total Deaths': [], 'Total Discharged': []}

# %%
l=[]
for i in rows:
  if i[0][0] in 'AEIOU':
    l.append((i[0],i[4],i[3]))
    # d['State'].append(i[0])
    # d['Total Deaths'].append(i[4])
    # d['Total Discharged'].append(i[4])

# %%
l
# Out:
# [('Andaman and Nicobar', '129', '9910'),
#  ('Andhra Pradesh', '14731', '2305076'),
#  ('Arunachal Pradesh', '296', '64207'),
#  ('Assam', '7986', '716235'),
#  ('Odisha', '9126', '1279083'),
#  ('Uttar Pradesh', '23518', '2054127'),
#  ('Uttarakhand', '7693', '429619')]

# %%
with open('/content/drive/MyDrive/CSV Assignment/summary_covid.csv','w') as f:
  wri=csv.DictWriter(f,['State','Total Deaths','Total Discharged'])
  wri.writeheader()
  for i in l:
    d_temp={'State':i[0],'Total Deaths':i[1],'Total Discharged':i[2]}
    wri.writerow(d_temp)

# %%
d
# Out:
# {'State': ['Andaman and Nicobar',
#   'Andhra Pradesh',
#   'Arunachal Pradesh',
#   'Assam',
#   'Odisha',
#   'Uttar Pradesh',
#   'Uttarakhand'],
#  'Total Deaths': ['129', '14731', '296', '7986', '9126', '23518', '7693'],
#  'Total Discharged': ['129', '14731', '296', '7986', '9126', '23518', '7693']}

# %%
print()
print(list(zip(d['State'],d['Total Deaths'],d['Total Discharged'])))
# Out:
# [('Andaman and Nicobar', '129', '129'), ('Andhra Pradesh', '14731', '14731'), ('Arunachal Pradesh', '296', '296'), ('Assam', '7986', '7986'), ('Odisha', '9126', '9126'), ('Uttar Pradesh', '23518', '23518'), ('Uttarakhand', '7693', '7693')]

# %%
with open('/content/drive/MyDrive/CSV Assignment/summary_covid.csv','w') as f:
  wri=csv.DictWriter(f,['State','Total Deaths','Total Discharged'])
  wri.writeheader()
  for i in zip(d['State'],d['Total Deaths'],d['Total Discharged']):
    d_temp={'State':i[0],'Total Deaths':i[1],'Total Discharged':i[2]}
    wri.writerow(d_temp)

# %%
#ques5
import csv
path='/content/drive/MyDrive/CSV Assignment/census_2011.csv'
with open(path,'r') as f:
  reader=csv.reader(f)
  data_census=[]
  for i in reader:
    data_census.append(i)

# %%
for i in data_census[:10]:
  print(i)
# Out:
# ['District code', 'State name', 'District name', 'Population', 'Male', 'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC', 'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST', 'Workers', 'Male_Workers', 'Female_Workers', 'Main_Workers', 'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers', 'Other_Workers', 'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains', 'Others_Religions', 'Religion_Not_Stated', 'LPG_or_PNG_Households', 'Housholds_with_Electric_Lighting', 'Households_with_Internet', 'Households_with_Computer', 'Rural_Households', 'Urban_Households', 'Households', 'Below_Primary_Education', 'Primary_Education', 'Middle_Education', 'Secondary_Education', 'Higher_Education', 'Graduate_Education', 'Other_Education', 'Literate_Education', 'Illiterate_Education', 'Total_Education', 'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50', 'Age not stated', 'Households_with_Bicycle', 'Households_with_Car_Jeep_Van', 'H
# ...

# %%
cols=data_census[0]

# %%
for i in enumerate(cols):
  print(i)
# Out:
# (0, 'District code')
# (1, 'State name')
# (2, 'District name')
# (3, 'Population')
# (4, 'Male')
# (5, 'Female')
# (6, 'Literate')
# (7, 'Male_Literate')
# (8, 'Female_Literate')
# (9, 'SC')
# (10, 'Male_SC')
# (11, 'Female_SC')
# (12, 'ST')
# (13, 'Male_ST')
# (14, 'Female_ST')
# (15, 'Workers')
# (16, 'Male_Workers')
# (17, 'Female_Workers')
# (18, 'Main_Workers')
# (19, 'Marginal_Workers')
# (20, 'Non_Workers')
# (21, 'Cultivator_Workers')
# (22, 'Agricultural_Workers')
# (23, 'Household_Workers')
# (24, 'Other_Workers')
# (25, 'Hindus')
# (26, 'Muslims')
# (27, 'Christians')
# (28, 'Sikhs')
# (29, 'Buddhists')
# (30, 'Jains')
# (31, 'Others_Religions')
# (32, 'Religion_Not_Stated')
# (33, 'LPG_or_PNG_Households')
# (34, 'Housholds_with_Electric_Lighting')
# (35, 'Households_with_Internet')
# (36, 'Households_with_Computer')
# (37, 'Rural_Households')
# (38, 'Urban_Households')
# (39, 'Households')
# (40, 'Below_Primary_Education')
# (41, 'Primary_Education')
# ...

# %%
for row in data_census:
  if row[1]=='UTTAR PRADESH' :
    print(row)
# Out:
# ['132', 'UTTAR PRADESH', 'Saharanpur', '3466382', '1834106', '1632276', '2077108', '1220114', '856994', '764450', '407029', '357421', '980', '517', '463', '1037344', '911136', '126208', '882701', '154643', '2429038', '221567', '273050', '34032', '508695', '1966892', '1454052', '6523', '18627', '1937', '10208', '135', '8008', '149035', '404499', '9699', '38816', '605082', '284156', '889238', '474060', '600668', '431491', '256510', '163463', '154153', '10083', '2090428', '1279517', '3369945', '2228689', '769736', '433862', '34095', '365960', '21310', '116358', '151620', '16788', '386772', '17404', '294410', '419470', '15910', '28835', '472744', '468873', '343084', '555491', '26897', '156879', '175', '70697', '15413', '2518', '11538', '120103', '239746', '276', '388400', '32', '726', '6262', '8812', '131048', '408736', '1792', '190539', '9937', '10249', '33995', '44244', '51906', '253552', '93215', '108431', '220551', '70629', '49192', '425406', '92433', '21262', '27238', '4667', '1309'
# ...

# %%
for row in data_census:
  if row[2]=='Ghaziabad' :
    print(row)
# Out:
# ['140', 'UTTAR PRADESH', 'Ghaziabad', '4681645', '2488834', '2192811', '3123264', '1811397', '1311867', '773463', '412750', '360713', '3968', '2104', '1864', '1520538', '1231615', '288923', '1252911', '267627', '3161107', '158868', '123680', '83672', '1154318', '3414427', '1186776', '19026', '23001', '3487', '16412', '265', '18251', '501592', '695130', '78116', '179552', '355407', '836316', '1191723', '534606', '858286', '797473', '597661', '475439', '255949', '26399', '3545813', '885070', '4430883', '2891069', '1139871', '559963', '90742', '409265', '119441', '218210', '292502', '62944', '577047', '117483', '592753', '700485', '60494', '19054', '785452', '750601', '701900', '672322', '140034', '122759', '1410', '21330', '19527', '9174', '12176', '79242', '122299', '484', '461559', '263', '446', '13148', '16550', '112973', '679606', '2693', '347916', '112059', '17906', '51607', '69513', '87682', '412399', '163121', '161596', '263640', '84291', '37264', '581289', '133968', '33996', '4
# ...

# %%
for row in data_census:
  if row[1]=='UTTAR PRADESH' and row[2]=='Lucknow':
    x=[row[2],row[cols.index('Literate')],row[cols.index('Housholds_with_Electric_Lighting')],row[cols.index('Households_with_Telephone_Mobile_Phone_Mobile_only')]]

# %%
x
# Out:
# ['Lucknow', '3127260', '582769', '506004']

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/CSV Assignment/Salaries.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df['BasePay'].astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e2d647413154> in <module>()
# ----> 1 df['BasePay'].astype(np.float64)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df[df['BasePay']=='Not Provided']
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148650  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148651  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148652  Not Provided  Not Provided       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN

# %%
df['BasePay'].unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '6.04', '15.50',
#        'Not Provided'], dtype=object)

# %%
df=df[df['BasePay']!='Not Provided']

# %%
df['BasePay'].unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '17.26', '6.04', '15.50'],
#       dtype=object)

# %%
df['BasePay']=df['BasePay'].astype(np.float64)

# %%
df['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
df['OvertimePay']=df['OvertimePay'].astype(np.float64)

# %%
df['OvertimePay'].max()
# Out:
# 245131.88

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25      NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13    106088.18    16452.6      NaN  335279.91         335279.91
# 3   77916.00     56120.71   198306.9      NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df.loc[0,'JobTitle']='abc'

# %%
df.head()
# Out:
#    Id       EmployeeName                                      JobTitle  \
# 0   1     NATHANIEL FORD                                           abc
# 1   2       GARY JIMENEZ               CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25      NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13    106088.18    16452.6      NaN  335279.91         335279.91
# 3   77916.00     56120.71   198306.9      NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df[df['JobTitle']=='abc']['JobTitle']='bcv'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#    Id       EmployeeName                                      JobTitle  \
# 0   1     NATHANIEL FORD                                           abc
# 1   2       GARY JIMENEZ               CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25      NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13    106088.18    16452.6      NaN  335279.91         335279.91
# 3   77916.00     56120.71   198306.9      NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df.iloc[1:3,2:4]
# Out:
#                           JobTitle    BasePay
# 1  CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2  CAPTAIN III (POLICE DEPARTMENT)  212739.13

# %%
df.loc[5:6]
# Out:
#    Id    EmployeeName                            JobTitle    BasePay  \
# 5   6  DAVID SULLIVAN           ASSISTANT DEPUTY CHIEF II  118602.00
# 6   7       ALSON LEE  BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
#
#    OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 5       8601.0  189082.74      NaN  316285.74         316285.74  2011    NaN
# 6      89062.9  134426.14      NaN  315981.05         315981.05  2011    NaN
#
#           Agency Status
# 5  San Francisco    NaN
# 6  San Francisco    NaN
