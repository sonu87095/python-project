# %%
import numpy as np
import pandas as pd

# %%
np.random.rand(5,5)
# Out:
# array([[0.59036589, 0.21846136, 0.82657816, 0.5872014 , 0.67431592],
#        [0.08200141, 0.87277784, 0.9318032 , 0.68329114, 0.84541644],
#        [0.83161439, 0.29391542, 0.25332564, 0.11826638, 0.3974472 ],
#        [0.16584729, 0.28140674, 0.40064794, 0.70120919, 0.07938752],
#        [0.73307037, 0.45972236, 0.28296717, 0.18640193, 0.6113885 ]])

# %%
df=pd.DataFrame(np.random.rand(5,5),index = ["a","b","c","d","e"],columns= ["p","q","r","s","t"])

# %%
df
# Out:
#           p         q         r         s         t
# a  0.092627  0.609760  0.767833  0.193174  0.182763
# b  0.255968  0.559573  0.459320  0.559310  0.977416
# c  0.402007  0.921039  0.542319  0.342851  0.109888
# d  0.663489  0.686699  0.676756  0.303408  0.590909
# e  0.915262  0.615305  0.033981  0.267144  0.793910

# %%
df[['p','s']]
# Out:
#           p         s
# a  0.092627  0.193174
# b  0.255968  0.559310
# c  0.402007  0.342851
# d  0.663489  0.303408
# e  0.915262  0.267144

# %%
df.loc['a']
# Out:
# p    0.092627
# q    0.609760
# r    0.767833
# s    0.193174
# t    0.182763
# Name: a, dtype: float64

# %%
df
# Out:
#           p         q         r         s         t
# a  0.092627  0.609760  0.767833  0.193174  0.182763
# b  0.255968  0.559573  0.459320  0.559310  0.977416
# c  0.402007  0.921039  0.542319  0.342851  0.109888
# d  0.663489  0.686699  0.676756  0.303408  0.590909
# e  0.915262  0.615305  0.033981  0.267144  0.793910

# %%
df["u"] = np.random.randn(5,1)

# %%
df
# Out:
#           p         q         r         s         t         u
# a  0.092627  0.609760  0.767833  0.193174  0.182763  0.276688
# b  0.255968  0.559573  0.459320  0.559310  0.977416  1.344037
# c  0.402007  0.921039  0.542319  0.342851  0.109888 -0.791431
# d  0.663489  0.686699  0.676756  0.303408  0.590909 -0.137630
# e  0.915262  0.615305  0.033981  0.267144  0.793910  0.954643

# %%
df.drop('u', axis = 1)
# Out:
#           p         q         r         s         t
# a  0.092627  0.609760  0.767833  0.193174  0.182763
# b  0.255968  0.559573  0.459320  0.559310  0.977416
# c  0.402007  0.921039  0.542319  0.342851  0.109888
# d  0.663489  0.686699  0.676756  0.303408  0.590909
# e  0.915262  0.615305  0.033981  0.267144  0.793910

# %%
df["u","v"] = np.random.randn(5,1)

# %%
df
# Out:
#           p         q         r         s         t         u    (u, v)
# a  0.092627  0.609760  0.767833  0.193174  0.182763  0.276688 -0.379622
# b  0.255968  0.559573  0.459320  0.559310  0.977416  1.344037 -0.544536
# c  0.402007  0.921039  0.542319  0.342851  0.109888 -0.791431  0.272170
# d  0.663489  0.686699  0.676756  0.303408  0.590909 -0.137630 -0.487680
# e  0.915262  0.615305  0.033981  0.267144  0.793910  0.954643  0.165529

# %%
tuple1=(5,7,9) 
tuple3=tuple1*2
print(tuple3)
# Out:
# (5, 7, 9, 5, 7, 9)

# %%
tupl=([7,5],"xyz",2,4) 
tupl[0][1]=1

# %%
str1="7/5" 
print("str1")
# Out:
# str1

# %%
a={3:"X",2:"B",7:"C"}
b=a.copy()
b[2]="D" 
print(a)
# Out:
# {3: 'X', 2: 'B', 7: 'C'}

# %%
z = 'pqrs'
for i in range(len(z)):
  i[x].upper()
  print (z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3bd788f8e545> in <module>()
#       1 z = 'pqrs'
#       2 for i in range(len(z)):
# ----> 3   i[x].upper()
#       4   print (z)
#
# NameError: name 'x' is not defined

# %%
sum = 0 
values = [1,3,5,7]
for number in values: sum = sum + number 
print(sum)
# Out:
# 16

# %%
x = 'pqrs' 
for i in x: 
  print(i)
  x.upper()
# Out:
# p
# q
# r
# s

# %%
for i in range(len(x)):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
x = 'pqrs' 
for i in range(len(x)): 
  x[i].upper() 
 
print(x)
# Out:
# pqrs

# %%
True = False 
while True: 
  print(True) 
  break
# Out:
#   File "<ipython-input-44-96155f6718cc>", line 1
#     True = False
#                  ^
# SyntaxError: can't assign to keyword

# %%
i = 2 
while True: 
  if i%3 == 0: 
    break
    print(i) 
    
  i += 2

# %%
list1=["john","arya","simon"]
list1.insert(5,8) 
print(list1)
# Out:
# ['john', 'arya', 'simon', 8]

# %%
import numpy as np 
a = np.array([1,2,3])
print (a)
# Out:
# [1 2 3]
