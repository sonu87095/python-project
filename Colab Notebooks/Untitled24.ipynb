# %%
import csv

# %%
import pandas as pd

# %%
with open('/content/births_usa.csv','r') as f:
  reader=csv.reader(f)
  l=[]
  for i in reader:
    l.append(i)

# %%
for j in l[:10]:
  print(j)
# Out:
# ['year', 'month', 'date_of_month', 'day_of_week', 'births']
# ['2000', '1', '1', '6', '9083']
# ['2000', '1', '2', '7', '8006']
# ['2000', '1', '3', '1', '11363']
# ['2000', '1', '4', '2', '13032']
# ['2000', '1', '5', '3', '12558']
# ['2000', '1', '6', '4', '12466']
# ['2000', '1', '7', '5', '12516']
# ['2000', '1', '8', '6', '8934']
# ['2000', '1', '9', '7', '7949']

# %%
# Out:
# ['2000', '1', '1', '6', '9083']

# %%
d={}
for i in l[1:]:
  if i[1] in d.keys():
    d[i[1]]=d[i[1]]+int(i[4])
  else:
    d[i[1]]=int(i[4])
print(d)
# Out:
# {'1': 5072588, '2': 4725693, '3': 5172961, '4': 4960750, '5': 5195445, '6': 5163360, '7': 5450418, '8': 5540170, '9': 5399592, '10': 5302865, '11': 5008750, '12': 5194432}

# %%
l[1]
# Out:
# ['2000', '1', '1', '6', '9083']
