# %%
#Calculate square loss and Absolute Error lo
Actual = [2,6,1,7,-9,5]


Real = [5,8,3,12,-9,0]
n = 6
sum = 0
  
# for loop for iteration
for i in range(n):
    sum += abs(Actual[i] - Real[i])
  
error = sum/n
  
# display
print("Mean absolute error : " + str(error))
# Out:
# Mean absolute error : 2.8333333333333335

# %%
from sklearn.metrics import mean_squared_error
Actual = [2,6,1,7,-9,5]
Real = [5,8,3,12,-9,0]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/1.01. Simple linear regression.csv')
df
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['SAT'],df['GPA'],color = 'r')
plt.xlabel('SAT')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')
