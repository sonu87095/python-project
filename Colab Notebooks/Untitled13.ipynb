# %%
n =int(input())
if n %2!=0:
    print("Weird")
else:
    if n in range(2,5):
        print("Not Weird")
    elif n in range(6,20):
        print("Weird")
    else:
        print("Not Weird")
# Out:
# 20
# Not Weird

# %%
N = int(input())
for i in range(1,N+1):
    if i%5==0:
        print("Masai")
    if i%5==0 and i%7==0:
        print("MasaiSchool")
    elif i%7==0:
        print("School")
    elif i%5==0 and i%7==0:
        print("MasaiSchoo")
    else:
      print(i)
# Out:
# 15
# 1
# 2
# 3
# 4
# Masai
# 5
# 6
# School
# 8
# 9
# Masai
# 10
# 11
# 12
# 13
# School
# Masai
# 15
