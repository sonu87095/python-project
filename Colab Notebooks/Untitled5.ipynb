# %% [markdown]
# Q (1) PRINT  data type of x,y,z

# %%
x = 25
print(type(x))
# Out:
# <class 'int'>

# %%
y = "preapleaf"
print(type(y))
# Out:
# <class 'str'>

# %%
z= 25.89
print(type(z))
# Out:
# <class 'float'>

# %% [markdown]
# Q2 take following as the input as users?

# %%
name = input("enter your favourite name :- ")
number = int(input("enter your lucky number:- "))
place = input("enter your favourite place ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-37ca87b5de5f> in <module>()
# ----> 1 name = input("enter your favourite name :- ")
#       2 number = int(input("enter your lucky number:- "))
#       3 place = input("enter your favourite place ")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# Q3

# %%
# name = "sonu"
# age =25 
# print("hello guys! this is",name,"and I am",age,"year old")
# Out:
# hello guys! this is sonu and I am 25 year old

# %% [markdown]
# Q 4 take two number as a input and print their
# sum,
# difference,
# product,
# divison,
# remainder

# %%
# num1 = int(input(" enter the number :- "))
# num2 = int(input("enter the number :-"))
# s= num1+num2
# print("sum :-",s)
# d= num1-num2
# print("difference :-",d)
# p = num1*num2 
# print("product:- ", p)
# r= num1%num2
# print("remainder",r)

# %% [markdown]
# Q 5 CHECK THE OUTPUT OF THE FOLLOWING

# %%
2==3
# Out:
# False

# %%
(2<3)
# Out:
# True

# %%
(2==2)
# Out:
# True

# %%
(4>5)
# Out:
# False

# %%
((23==2)&(2==3))
# Out:
# False

# %%
((23==2)|(2==3))
# Out:
# False

# %% [markdown]
# 6  take a number input from user and print the following

# %%
num = int(input(" enter a number :-"))
if num%2==0 and num<100:
  print("number is even and less than 100 ")
elif num%2!=0 and num<100:
  print("number is odd and less than 100")
elif num>100:
  print("out of bounds")
# Out:
#  enter a number :-45
# number is odd and less than 100

# %% [markdown]
# Q6 write a program to print multiplicatin upto 10 of given number

# %%
num = 2 
for a in range(1,11):
 print("2*",a ,"=", 2*a)
# Out:
# 2* 1 = 2
# 2* 2 = 4
# 2* 3 = 6
# 2* 4 = 8
# 2* 5 = 10
# 2* 6 = 12
# 2* 7 = 14
# 2* 8 = 16
# 2* 9 = 18
# 2* 10 = 20

# %% [markdown]
# Q7 write a program to count the total number of digit in a number ?

# %%
input = 258
len(str(input))
# Out:
# 3

# %% [markdown]
# write a program to display all the prime number within a range ?

# %%
a = int(input())
if a%a==0 and  a%1==a:
  print("a is prime number")
else :
  print("a is not prime number")
# Out:
# 17
# a is not prime number

# %% [markdown]
# i have runned all the code but if I treid to run it again it showing error:
# 'int' objects are not callable
