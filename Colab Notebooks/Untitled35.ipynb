# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Salaries (1).csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.isnull()
# Out:
#           Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0      False         False     False    False        False     False
# 1      False         False     False    False        False     False
# 2      False         False     False    False        False     False
# 3      False         False     False    False        False     False
# 4      False         False     False    False        False     False
# ...      ...           ...       ...      ...          ...       ...
# 30357  False         False     False    False        False     False
# 30358  False         False     False    False        False     False
# 30359  False         False     False    False        False     False
# 30360  False         False     False    False        False     False
# 30361  False          True      True     True         True      True
#
#        Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
df.describe()
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  Benefits  \
# count  30362.000000   30361.000000   30361.000000   30361.000000       0.0
# mean   15180.599993   74696.904818    5379.488587    4237.655611       NaN
# std     8764.742899   34452.939565   11261.837830    8532.614169       NaN
# min        1.000000       0.000000       0.000000       0.000000       NaN
# 25%     7590.250000   52076.660000       0.000000      46.000000       NaN
# 50%    15180.500000   68522.980000     349.900000    1280.000000       NaN
# 75%    22770.750000   97847.650000    5713.800000    5027.210000       NaN
# max    30361.000000  294580.020000  245131.880000  400184.250000       NaN
#
#             TotalPay  TotalPayBenefits     Year  Notes  Status
# count   30361.000000      30361.000000  30361.0    0.0     0.0
# mean    84314.049016      84314.049016   2011.0    NaN     NaN
# std     41207.910605      41207.910605      0.0    NaN     NaN
# ...

# %%
df['BasePay'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30357    False
# 30358    False
# 30359    False
# 30360    False
# 30361     True
# Name: BasePay, Length: 30362, dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# 295953

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df['BasePay'].isnull().sum()
# Out:
# 605

# %%
df.dropna(subset = ['BasePay'])
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
obj = pd.read_csv('/content/prac.csv')
obj
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4    neha     43      5   104         10

# %%
obj = pd.read_csv('/content/prac.csv')
obj
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4    neha     43      5   104         10

# %%
obj = pd.read_csv('prac.csv')
obj
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4    neha     43      5   104         10

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df.fillna(0)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
obj
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4    neha     43      5   104         10

# %%
obj.replace('neha','shilpi',inplace = True)

# %%
obj
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4  shilpi     43      5   104         10

# %%
obj.replace({'name':'sonu'},'none')
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4  shilpi     43      5   104         10

# %%
obj
# Out:
#     name   marks  class  fees  distance
# 0    sonu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4  shilpi     43      5   104         10

# %%
obj = obj.replace({'sonu':'sanu','guddu':'guddia','shilpi':'kutti'})

# %%
obj
# Out:
#     name   marks  class  fees  distance
# 0    sanu     30      1   100         10
# 1  guddu      40      2   101         10
# 2  sunita     41      3   102         10
# 3   vikas     42      4   103         10
# 4   kutti     43      5   104         10

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df.groupby('Year').mean()
# Out:
#             Id      TotalPay  TotalPayBenefits  Notes
# Year
# 2011   18080.0  71744.103871      71744.103871    NaN
# 2012   54542.5  74113.262265     100553.229232    NaN
# 2013   91728.5  77611.443142     101440.519714    NaN
# 2014  129593.0  75463.918140     100250.918884    NaN

# %%
x

# %%
df1 = pd.DataFrame([['10.0' ,6,7,8],
                   ['1.0' ,9,12,14],
                   ['5.0' ,8,10,6]],
                  columns = ['a','b','c','d'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      object
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
#  3   d       3 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 224.0+ bytes

# %%
df1['a'] = df1['a'].astype(float, errors = 'raise')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      float64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
#  3   d       3 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 224.0 bytes

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'],errors = 'coerce')

# %%
df['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 14.7+ MB
