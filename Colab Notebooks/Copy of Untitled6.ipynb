# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

# %%
#csv library
#two works
#1-reading the csv file
#2-writing into csv file

# %%
with open('/content/drive/MyDrive/CSV Assignment/births_usa.csv','r') as f:
  reader=csv.reader(f)
  l=[]
  for i in reader:
    l.append(i)

# %%
l

# %%
for j in l[:10]:
  print(j)
# Out:
# ['year', 'month', 'date_of_month', 'day_of_week', 'births']
# ['2000', '1', '1', '6', '9083']
# ['2000', '1', '2', '7', '8006']
# ['2000', '1', '3', '1', '11363']
# ['2000', '1', '4', '2', '13032']
# ['2000', '1', '5', '3', '12558']
# ['2000', '1', '6', '4', '12466']
# ['2000', '1', '7', '5', '12516']
# ['2000', '1', '8', '6', '8934']
# ['2000', '1', '9', '7', '7949']

# %%
d={}
for i in l[1:]:
  if i[1] in d.keys():
    d[i[1]]=d[i[1]]+int(i[4])
  else:
    d[i[1]]=int(i[4])
print(d)
# Out:
# {'1': 5072588, '2': 4725693, '3': 5172961, '4': 4960750, '5': 5195445, '6': 5163360, '7': 5450418, '8': 5540170, '9': 5399592, '10': 5302865, '11': 5008750, '12': 5194432}

# %%
lst=['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
v=[]
for i in d.items():
  v.insert(int(i[0])-1,i[1])
print(v)
# Out:
# [5072588, 4725693, 5172961, 4960750, 5195445, 5163360, 5450418, 5540170, 5399592, 5302865, 5008750, 5194432]

# %%
with open('temp1.csv','w') as f:
  writer=csv.writer(f)
  writer.writerow(lst)
  writer.writerow(v)

# %%
d
# Out:
# {'1': 5072588,
#  '10': 5302865,
#  '11': 5008750,
#  '12': 5194432,
#  '2': 4725693,
#  '3': 5172961,
#  '4': 4960750,
#  '5': 5195445,
#  '6': 5163360,
#  '7': 5450418,
#  '8': 5540170,
#  '9': 5399592}

# %%
d1={}  #key=5 value=25
d1[5]=25

# %%
d1
# Out:
# {5: 25}

# %%
d1[5]=20

# %%
d1
# Out:
# {5: 20}

# %%
d1[5]=1

# %%
d1
# Out:
# {5: 1}

# %%
d[5]=3

# %%
d1[5]=d1[5]+2

# %%
d1[5]
# Out:
# 3

# %%
d1[5]+2
# Out:
# 5

# %%
d1[5]=2

# %%
d1
# Out:
# {1: 2, 5: 2}

# %%
for k,v in d1.items():
  sum=v+sum

# %%
d[5]+=3 #d[5]=d[5]+3

# %%
d1 = {5:1} 
d1[5]+=1 
d1
# Out:
# {5: 2}

# %%
d1.keys()
# Out:
# dict_keys([5])

# %%
d1[5]=d1[5]+8

# %%
d1[5]
# Out:
# 10

# %%
d[5]
# Out:
# 7

# %%
dict={'key':'value', 'key2': 'value2'}

# %%
d
# Out:
# {'1': '...',
#  '10': '...',
#  '11': '...',
#  '12': '...',
#  '2': '...',
#  '3': '...',
#  '4': '...',
#  '5': '...',
#  '6': '...',
#  '7': '...',
#  '8': '...',
#  '9': '...'}

# %%
#writing 
with open('/content/drive/MyDrive/CSV Assignment/temp.csv','w') as f:
  writer=csv.writer(f)
  for i in l[:10]:
    writer.writerow(i)

# %%
help(csv.writer)
# Out:
# Help on built-in function writer in module _csv:
#
# writer(...)
#     csv_writer = csv.writer(fileobj [, dialect='excel']
#                                 [optional keyword args])
#         for row in sequence:
#             csv_writer.writerow(row)
#
#         [or]
#
#         csv_writer = csv.writer(fileobj [, dialect='excel']
#                                 [optional keyword args])
#         csv_writer.writerows(rows)
#
#     The "fileobj" argument can be any object that supports the file API.

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/CSV Assignment/births_usa.csv')

# %%
df.head()
# Out:
#    year  month  date_of_month  day_of_week  births
# 0  2000      1              1            6    9083
# 1  2000      1              2            7    8006
# 2  2000      1              3            1   11363
# 3  2000      1              4            2   13032
# 4  2000      1              5            3   12558

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5479 entries, 0 to 5478
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           5479 non-null   int64
#  1   month          5479 non-null   int64
#  2   date_of_month  5479 non-null   int64
#  3   day_of_week    5479 non-null   int64
#  4   births         5479 non-null   int64
# dtypes: int64(5)
# memory usage: 214.1 KB

# %%
d_m={1:'jan',2:'feb',3:'mar',4:'apr',5:'may',6:'jun',7:'jul',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'}

# %%
df['month'].map(d_m)
# Out:
# 0       jan
# 1       jan
# 2       jan
# 3       jan
# 4       jan
#        ...
# 5474    dec
# 5475    dec
# 5476    dec
# 5477    dec
# 5478    dec
# Name: month, Length: 5479, dtype: object

# %%
'''
Question #3
- File `cart_class.py`
- Define a new class named "ShoppingCart"
- Declare an attribute of this class called items_present_in_cart which is 'dict' type
container that stores name and price of product as key-value
- Define the __init__() function of the ShoppingCart class to take two inputs: self,
customer_id
- Add two methods to the class: add_item and remove_item
- add_item methods receives parameters product and price and if that product is not
already present in the cart (items_present_in_cart) then add that item and print
"[Name of the product] Added", else print "[Name of the product] is already present"
- Similarly, remove_item method removes product from cart in case it is already there
and prints the same. If that product is not present, it prints "[Name of the product] not
present in cart.
'''

# %%
class ShoppingCart:
  items_present_in_cart={}

  def __init__(self,customer_id):
    self.customer_id=customer_id
  def add_item(self,product,price):
    if product not in self.items_present_in_cart.keys():
      self.items_present_in_cart[product]=price
      print(product,' added')
    else:
      print(product,' is already present')

  def remove_item(self,product):
    if product in self.items_present_in_cart.keys():
      del self.items_present_in_cart[product]
      print(product)
    else:
      print(product,' not present in cart')

# %%
a=ShoppingCart(1)

# %%
a.remove_item('milk')
# Out:
# milk  not present in cart

# %%
a.add_item('milk',20)
# Out:
# milk  added

# %%
a.items_present_in_cart
# Out:
# {'milk': 20}

# %%
a.add_item('curd',30)
# Out:
# curd  added

# %%
a.items_present_in_cart
# Out:
# {'curd': 30, 'milk': 20}

# %%
a.add_item('milk',20)
# Out:
# milk  is already present

# %%
a.items_present_in_cart
# Out:
# {'curd': 30, 'milk': 20}

# %%
a.remove_item('milk')
# Out:
# milk

# %%
a.items_present_in_cart
# Out:
# {'curd': 30}

# %%
a.remove_item('milk')
# Out:
# milk  not present in cart
