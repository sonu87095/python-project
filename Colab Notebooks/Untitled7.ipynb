# %%
sex, marital = map(str,input().split())
age = int(input())
# Out:
# M Y
# 23

# %%
l =["sonu","neha","khushi","shilpi"]
s=[]
for i in l:
  s.append(i)
print(s)
# Out:
# ['sonu', 'neha', 'khushi', 'shilpi']
